# %% [markdown]
# - 작성자: 이예빈

# %%
import pandas as pd
import numpy as np
import re
from konlpy.tag import Okt
import numpy as np
import pandas as pd
import os
import re
from konlpy.tag import Okt
import matplotlib.pyplot as plt
from wordcloud import WordCloud
import tqdm

# %%
df_all = pd.read_csv('./1-8월 뉴스.csv')
df_all.head()
# Out:
#                                         title  \
# 0                   무너지는 일과 삶의 경계···노동이 녹아내린다
# 1        일자리 아닌 일거리···'일정치 않음'을 살다 [녹아내리는 노동]
# 2  이곳은…기계의 정확도 높이는 ‘인간부품’ 육성공장 아닐까 [녹아내리는 노동]
# 3                      지혜씨, 지훈씨를 부탁해! [인포그래픽]
# 4        [20대 리포트] “20대, 함부로 판단말라… 내 길 내가 간다”
#
#                                                 text  \
# 0  이 땅에서 ‘비정규직’이라는 표현이 광범위하게 쓰인 지 20여년. 정부가 신규 일자...
# 1  ㆍ①일자리보다 일거리\n\n노동의 미래를 모두 알 수는 없다. 다만 현실에서 일어나...
# 2  ㆍ①일자리보다 일거리\n\nㆍAI 학습데이터 가공 기업 ‘크라우드웍스’ 교육장 참관...
# 3  새로 태어나는 아이들은 줄어들고 어르신들은 계속 나이를 먹어 갑니다. 2020년 새...
# 4  새천년의 시작과 함께 세상에 나온 2000년대생들이 어느덧 사회 변화를 이끌 20대...
#
#                                                  url media        date
# 0  https://news.naver.com/main/read.nhn?mode=LPOD...  경향신문  2020-01-01
# 1  https://news.naver.com/main/read.nhn?mode=LPOD...  경향신문  2020-01-01
# 2  https://news.naver.com/main/read.nhn?mode=LPOD...  경향신문  2020-01-01
# 3  https://news.naver.com/main/read.nhn?mode=LPOD...  경향신문  2020-01-01
# ...

# %%
news_media_all = list(set(df_all['media']))

# %%
news_media_all
# Out:
# ['세계일보', '한겨레', '조선일보', '중앙일보', '동아일보', '경향신문', '국민일보', '한국일보', '문화일보', '서울신문']

# %%
for n in news_media_all:
    print(type(n))
# Out:
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>

# %%
for news_media in news_media_all:
#     news_media_all.query('media.str.conrains("서울")')
    tmp_list = df_all[df_all['media'] == news_media]
    tmp_list.to_csv('./tokenized_news/' + news_media, encoding='utf-8')

# %%
aa = pd.read_csv('./tokenized_news/경향신문')
aa
# Out:
#       Unnamed: 0                                        title  \
# 0              0                    무너지는 일과 삶의 경계···노동이 녹아내린다
# 1              1         일자리 아닌 일거리···'일정치 않음'을 살다 [녹아내리는 노동]
# 2              2   이곳은…기계의 정확도 높이는 ‘인간부품’ 육성공장 아닐까 [녹아내리는 노동]
# 3              3                       지혜씨, 지훈씨를 부탁해! [인포그래픽]
# 4             85  김정은 “머지않아 새 전략무기 목격하게 될 것” [북 노동당 전원회의 결정서]
# ...          ...                                          ...
# 3710       28903          전 세계 확진자 수, 20일 만에 500만 늘며 2500만 넘어
# 3711       28904                 코로나 여파…4년제 대학 절반 이상 대입 전형 변경
# 3712       28905            역성장 넘어 경기회복 희망마저 꺼질 판…정책 질적 전환할 때
# 3713       28906     정부, 자영업자·취약계층 추가 지원…3조원 이내 경기보강 대책 9월 발표
# 3714       28907                          일자리 스톱·스톱…“추석이 두렵다”
#
#                                                    text  \
# 0     이 땅에서 ‘비정규직’이라는 표현이 광범위하게 쓰인 지 20여년. 정부가 신규 일자...
# 1     ㆍ①일자리보다 일거리\n\n노동의 미래를 모두 알 수는 없다. 다만 현실에서 일어나...
# ...
