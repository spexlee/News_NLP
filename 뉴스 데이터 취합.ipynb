# %%
import pandas as pd

# %%
aa = pd.read_csv('../../data/tokenized_news/tokenized_news_textile_okt_nouns_all')

# %%
cc = pd.read_csv('../../data/tokenized_news/tokenized_news_textile_okt_nouns_all')

# %%
bb = pd.read_csv('../../data/tokenized_news/tokenized_news_title_okt_nouns_all')

# %%
bb['title_'] = aa['title']

# %%
aa['text_V'] = cc['text']

# %%
aa['title_V'] = bb['title']

# %%
aa['text'] = bb['text']

# %%
aa['title'] = bb['title_']

# %%
aa
# Out:
#        Unnamed: 0                                         title  \
# 0               0                     무너지는 일과 삶의 경계···노동이 녹아내린다
# 1               1          일자리 아닌 일거리···'일정치 않음'을 살다 [녹아내리는 노동]
# 2               2    이곳은…기계의 정확도 높이는 ‘인간부품’ 육성공장 아닐까 [녹아내리는 노동]
# 3               3                        지혜씨, 지훈씨를 부탁해! [인포그래픽]
# 4               4          [20대 리포트] “20대, 함부로 판단말라… 내 길 내가 간다”
# ...           ...                                           ...
# 29036       29036           "2.5단계로 무급휴가 요구"… 코로나 재유행에 살아난 '갑질'
# 29037       29037  모호한 조치ㆍ 깜깜이 환자 비율 40%육박... 거리두기 2.5단계 효과 있을까
# 29038       29038          내일부터 서울 시내버스 밤 9시 이후 20% 감축… 주말 수준으로
# 29039       29039    집단휴업 두고 전공의 vs 정부 '강대강 대치'... 의료공백 장기화 불가피
# 29040       29040            "제자 한명이라도 피해 입으면 집단휴진" 의대 교수까지 화났다
#
#                                                     text  \
# 0      이 땅에서 ‘비정규직’이라는 표현이 광범위하게 쓰인 지 20여년. 정부가 신규 일자...
# 1      ㆍ①일자리보다 일거리\n\n노동의 미래를 모두 알 수는 없다. 다만 현실에서 일어나...
# ...

# %%
bb = aa.drop(columns='Unnamed: 0')

# %%
bb.to_csv('../../data/tokenized_news/tokenized_all')

# %%
bb
# Out:
#                                               title  \
# 0                         무너지는 일과 삶의 경계···노동이 녹아내린다
# 1              일자리 아닌 일거리···'일정치 않음'을 살다 [녹아내리는 노동]
# 2        이곳은…기계의 정확도 높이는 ‘인간부품’ 육성공장 아닐까 [녹아내리는 노동]
# 3                            지혜씨, 지훈씨를 부탁해! [인포그래픽]
# 4              [20대 리포트] “20대, 함부로 판단말라… 내 길 내가 간다”
# ...                                             ...
# 29036           "2.5단계로 무급휴가 요구"… 코로나 재유행에 살아난 '갑질'
# 29037  모호한 조치ㆍ 깜깜이 환자 비율 40%육박... 거리두기 2.5단계 효과 있을까
# 29038          내일부터 서울 시내버스 밤 9시 이후 20% 감축… 주말 수준으로
# 29039    집단휴업 두고 전공의 vs 정부 '강대강 대치'... 의료공백 장기화 불가피
# 29040            "제자 한명이라도 피해 입으면 집단휴진" 의대 교수까지 화났다
#
#                                                     text  \
# 0      이 땅에서 ‘비정규직’이라는 표현이 광범위하게 쓰인 지 20여년. 정부가 신규 일자...
# 1      ㆍ①일자리보다 일거리\n\n노동의 미래를 모두 알 수는 없다. 다만 현실에서 일어나...
# 2      ㆍ①일자리보다 일거리\n\nㆍAI 학습데이터 가공 기업 ‘크라우드웍스’ 교육장 참관...
# 3      새로 태어나는 아이들은 줄어들고 어르신들은 계속 나이를 먹어 갑니다. 2020년 새...
# ...
