# %% [markdown]
# ## 날짜별 워드 클라우드로 가장 빈도수 높은 단어 도출 (title)
# - 이예빈
# - 참고:
#     - 불용어 리스트 (https://www.ranks.nl/stopwords/korean)
#     - 불용어 리스트(https://gist.github.com/spikeekips/40eea22ef4a89f629abd87eed535ac6a)

# %%
import pandas as pd
import numpy as np
import re
from konlpy.tag import Mecab
import numpy as np
import pandas as pd
import os
import re
import matplotlib.pyplot as plt
from wordcloud import WordCloud
import tqdm

# %%
try:
    if not(os.path.isdir('../data/tokenized_news')):
        os.makedirs(os.path.join('../tokenized_news'))
                    
except OSError as e:
    if e.errno != errno.EEXIST:
        print("Failed to create directory!")
        raise

# %%
# CSV_List로 만드는 함수
def csv2list(filename):
    lists = []
    file = open(filename,'r',encoding='utf-8')
    while True:
        line = file.readline().rstrip('\n')
        if line:
            lists.append(line)
        else:
            break
    return lists

# %%
stop_words = csv2list('../data/stop_words/stop_words.csv')

# %%
### 뉴스 제목에서 기호 제거 & 명사 추출 

def textile_preprocessing(text, mecab):
    textile_text = re.sub('[^가-힣ㄱ-ㅎㅏ-ㅣ\\s]', ' ', text)
    word_textile = mecab.morphs(textile_text) 
    word_textile = [word for word in word_textile if not word in stop_words] # 불용어 제거
    
    return word_textile

# %%
### 전처리된 데이터프레임 by_day를 반환합니다. 
## file: csv파일이 들어있는 경로를 지정해주세요. (+ 파일까지 포함되도록!)

def all_preprocessing(file):
    df_file = pd.read_csv(file, encoding='utf-8')
    
    textile = df_file['text']
    date_ = df_file['date']
    df_file = pd.DataFrame({'text':textile, 'date':date_})
    
    mecab = Mecab(dicpath=r"C:\mecab\mecab-ko-dic")
    clean_text = []
    for text in df_file['text']:
        if type(text)==str:
            clean_text.append(textile_preprocessing(text, mecab))
        else:
            clean_text.append([])
    df['text'] = clean_text
    
    # date 컬럼 -> datetime으로 설정 
    df_file['date'] = pd.to_datetime(df_file['date'])
    by_day = df_file.groupby(df_file['date']).sum()

    # 딕셔너리 풀기
    title_textile = []
    for i in range(len(by_day['text'])):
        title_textile.append(', '.join(by_day['text'][i]))

    by_day['text'] = title_textile
    
    by_day.to_csv('../data/tokenized_news/tokenized_news_textile_mecab_morphs' , encoding='utf-8')
    
    return by_day

# %%
all_preprocessing('./1-8월 뉴스.csv')
# Out:
#                                                         title  \
# date
# 2020-01-01  무너지는 일과 삶의 경계···노동이 녹아내린다일자리 아닌 일거리···'일정치 않음'...
# 2020-01-02  김정은 “머지않아 새 전략무기 목격하게 될 것” [북 노동당 전원회의 결정서]작년 ...
# 2020-01-03  엽서·쿡방·팬시·팬덤…밀레니얼의 ‘5·18 기억법’외교부 "이라크 정세 불안과 한국...
# 2020-01-04  ‘썩은 계란의 피라미드’를 깨다 [커버스토리]미 공습에 이란혁명수비대 ‘실세’ 사망...
# 2020-01-05  1월6일 서울, 세계 최악의 도시 3위? [오래 전 ‘이날’](5)새해에만 굳건한 ...
# ...                                                       ...
# 2020-08-27  업무개시명령에도 의료계 총파업 강행또 트럼프가 되는 걸까? …11월 미국 대선 세가...
# 2020-08-28  거리 두기 2단계에도 꺾이지 않는 코로나 재확산의·정 대화 단절 속…응급·중환자실 ...
# 2020-08-29  의사 파업 속…의정부·부산서 응급실 찾아 헤매던 환자 숨져‘지병 악화’ 아베 일본 ...
# 2020-08-30                             팔다리 쭉 뱃살은 쏙… 집에서도 날씬하게
# 2020-08-31  늘어난 코로나 사망…위중증 환자도 2주 새 ‘5배’대세 입증 이낙연…‘이중 시험대’...
#
#                                                          text  \
# date
# 2020-01-01  이,  , 땅, 에, 서,  , ‘, 비, 정, 규, 직, ’, 이, 라, 는,  ...
# 2020-01-02  ㆍ, 북,  , 노, 동, 당,  , 중, 앙, 위,  , 전, 원, 회, 의,  ...
# 2020-01-03  ㆍ, 5, ·, 1, 8, 민, 주, 화, 운, 동,  , 4, 0, 주, 기, …...
# 2020-01-04  ㆍ, 고, 은, 과, 의,  , ‘, 미, 투,  , 소, 송, ’, 에, 서,  ...
# 2020-01-05  1, 9, 6, 0, 년, 부, 터,  , 2, 0, 1, 0, 년, 까, 지,  ...
# ...                                                       ...
# 2020-08-27  [, 경, 향, 신, 문, ],  , \n, \n, 대, 한, 의, 사, 협, 회,...
# 2020-08-28  [, 경, 향, 신, 문, ],  , \n, \n, \n, \n, 장, 기, 화, ...
# 2020-08-29  [, 경, 향, 신, 문, ],  , \n, \n, \n, \n, 의, 사, 들, ...
# 2020-08-30  《, 신, 종,  , 코, 로, 나, 바, 이, 러, 스,  , 감, 염, 증, (...
# 2020-08-31  [, 경, 향, 신, 문, ],  , \n, \n, \n, \n, 코, 로, 나, ...
#
#                                                           url  \
# date
# 2020-01-01  https://news.naver.com/main/read.nhn?mode=LPOD...
# 2020-01-02  https://news.naver.com/main/read.nhn?mode=LPOD...
# 2020-01-03  https://news.naver.com/main/read.nhn?mode=LPOD...
# 2020-01-04  https://news.naver.com/main/read.nhn?mode=LPOD...
# 2020-01-05  https://news.naver.com/main/read.nhn?mode=LPOD...
# ...                                                       ...
# 2020-08-27  https://news.naver.com/main/read.nhn?mode=LPOD...
# 2020-08-28  https://news.naver.com/main/read.nhn?mode=LPOD...
# 2020-08-29  https://news.naver.com/main/read.nhn?mode=LPOD...
# 2020-08-30  https://news.naver.com/main/read.nhn?mode=LPOD...
# 2020-08-31  https://news.naver.com/main/read.nhn?mode=LPOD...
#
#                                                         media
# date
# 2020-01-01  경향신문경향신문경향신문경향신문국민일보국민일보국민일보국민일보국민일보국민일보국민일보동아...
# 2020-01-02  경향신문경향신문경향신문경향신문경향신문경향신문경향신문경향신문경향신문경향신문국민일보국민...
# 2020-01-03  경향신문경향신문경향신문경향신문경향신문경향신문경향신문경향신문경향신문경향신문경향신문경향...
# 2020-01-04  경향신문경향신문경향신문경향신문경향신문경향신문경향신문경향신문경향신문국민일보국민일보국민...
# 2020-01-05                                           경향신문경향신문
# ...                                                       ...
# 2020-08-27  경향신문경향신문경향신문경향신문경향신문경향신문경향신문경향신문경향신문경향신문경향신문경향...
# 2020-08-28  경향신문경향신문경향신문경향신문경향신문경향신문경향신문경향신문경향신문경향신문경향신문경향...
# 2020-08-29  경향신문경향신문경향신문경향신문경향신문경향신문경향신문경향신문경향신문경향신문경향신문경향...
# 2020-08-30                                               동아일보
# 2020-08-31  경향신문경향신문경향신문경향신문경향신문경향신문경향신문경향신문경향신문경향신문경향신문경향...
#
# [231 rows x 4 columns]

# %%
df_file = pd.read_csv('../data/tokenized_news/tokenized_news_textile_okt_nouns_eng')

# %%
textile = df_file['text']
date_ = df_file['date']
df_file = pd.DataFrame({'text':textile, 'date':date_})
df_file.to_csv('../data/tokenized_news/tokenized_news_textile_mecab_nouns')

# %%
df_file
# Out:
#                                                   text        date
# 0    이,  , 땅, 에, 서,  , ‘, 비, 정, 규, 직, ’, 이, 라, 는,  ...  2020-01-01
# 1    ㆍ, 북,  , 노, 동, 당,  , 중, 앙, 위,  , 전, 원, 회, 의,  ...  2020-01-02
# 2    ㆍ, 5, ·, 1, 8, 민, 주, 화, 운, 동,  , 4, 0, 주, 기, …...  2020-01-03
# 3    ㆍ, 고, 은, 과, 의,  , ‘, 미, 투,  , 소, 송, ’, 에, 서,  ...  2020-01-04
# 4    1, 9, 6, 0, 년, 부, 터,  , 2, 0, 1, 0, 년, 까, 지,  ...  2020-01-05
# ..                                                 ...         ...
# 226  [, 경, 향, 신, 문, ],  , \n, \n, 대, 한, 의, 사, 협, 회,...  2020-08-27
# 227  [, 경, 향, 신, 문, ],  , \n, \n, \n, \n, 장, 기, 화, ...  2020-08-28
# 228  [, 경, 향, 신, 문, ],  , \n, \n, \n, \n, 의, 사, 들, ...  2020-08-29
# 229  《, 신, 종,  , 코, 로, 나, 바, 이, 러, 스,  , 감, 염, 증, (...  2020-08-30
# 230  [, 경, 향, 신, 문, ],  , \n, \n, \n, \n, 코, 로, 나, ...  2020-08-31
#
# [231 rows x 2 columns]

# %%
tmp_df.to_csv('./tokenized_news/tokenized_title_okt_nouns', encoding='utf-8')

# %%
aa = pd.read_csv('./1-8월 뉴스.csv')

# %%
okt = Okt()
clean_text = []
for text in aa['text']:
    if type(text)==str:
        
        textile_text = re.sub('[^가-힣ㄱ-ㅎㅏ-ㅣ\\s]', ' ', text)
        word_textile = okt.nouns(textile_text) 
        word_textile = [word for word in word_textile if not word in stop_words] # 불용어 제거
        
        clean_text.append(word_textile)
    else:
         clean_text.append([])
    
aa['text'] = clean_text

# %%
def daily_news_text_wordcloud(date_to_search):
    tmp_df = pd.read_csv('../data/tokenized_news/tokenized_news_textile_mecab_morphs', encoding='UTF-8')
    
    cloud = WordCloud(
      font_path='../../fonts/NanumSquareRoundR.ttf'
    , width=800
    , height=600
    , max_words=100
    ).generate(
        ''.join(tmp_df['text'][tmp_df['date']== date_to_search])
    )

    plt.figure(figsize=(20, 15))
    plt.imshow(cloud)
    plt.axis('off')

# %%
daily_news_text_wordcloud('2020-05-30')
